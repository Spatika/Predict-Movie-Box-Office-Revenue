# %% [markdown]
# # Box Office Revenue Prediction

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np


import re # regex
import ast

from datetime import datetime
from datetime import date

from sklearn import metrics
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import learning_curve, RandomizedSearchCV, train_test_split

# %% [markdown]
# ## Data Sources
# 1. IMDB:
#     * No. of ratings (star)
#     * Avg. star rating (out of 10)
#     * No. of user ratings (text reviews)
#     * No. of critic ratings (meta critic)
#     * Countries (truncate to just first country) - √
#     * Language (truncate to just first language) - √
#     * No. of languages (to be created from previous column) - √
#     * Production house (truncate to just first production house) - √
#     * Duration (convert to minutes/numeric from string) - √
#     * Genre (need to explode to one-hot columns for 24 genres) - √
#     * MPAA rating
#         * TV- ratings - reclassify - √
#         * Not Rated --> PG-13/Unrated --> PG - many from non-English fall under these categories - √
#
#     * **Gross:** 'Y' variable (need to remove movies with alphabet-only gross, convert INR (other currencies?) to USD and 3 INR 3-digit movies):
#         * **`TODO`** Adjust for inflation, based on year of release
#     * **`TODO`** Release date + release region - separate out into 2 columns:
#         * convert first to datetime and use as a feature (holiday - US - release/not)
#
#
# &nbsp;
# 2. Popularity Scores:
#     * Average popularity score per movie
#
# &nbsp;
#
# 3. Sentiment Scores (**`TODO`**):
#     * AFINN score - based on IMDB user reviews pre-release
#     * AFINN score - based on IMDB user reviews post-release
#
#
# &nbsp;
# 4. YouTube (**`TODO`**):
#     * View count
#     * Like count
#     * Dislike count
#     * Comment count

# %% [markdown]
# ## Reading Excel File(s)
# #### !!!!!! IMPORTANT- manually removed the unnamed serial number column from the excel sheet I'm reading below!!!!!
# #### Check that it is removed in your excel sheet also

# %%
# read xlsx with IMDB_ID as the indexing column (2nd column from the left, or 1st column) 
df = pd.read_excel("Final_data_sheets_updated_popularity_scores.xlsx", index_col = 0)

# %%
# inspect
df.head(10)
# Out:
#                            Name  num_ratings  avg_rating  \
# IMDB_ID
# 433362              Daybreakers       116014         6.5
# 1216492               Leap Year        85208         6.5
# 1037705         The Book of Eli       268523         6.9
# 1038686                  Legion        91364         5.2
# 1244659  Extraordinary Measures        15595         6.5
# 1185416            When in Rome        57030         5.6
# 1226273        Edge of Darkness        84196         6.6
# 817230          Valentine's Day       106464         5.7
# 780653              The Wolfman        97229         5.8
# 1130884          Shutter Island       991065         8.1
#
#                                         main_cast_list  \
# IMDB_ID
# 433362              Ethan Hawke|Willem Dafoe|Sam Neill
# 1216492             Amy Adams|Matthew Goode|Adam Scott
# 1037705     Denzel Washington|Mila Kunis|Ray Stevenson
# 1038686    Paul Bettany|Dennis Quaid|Charles S. Dutton
# 1244659      Brendan Fraser|Keri Russell|Harrison Ford
# 1185416      Kristen Bell|Josh Duhamel|Anjelica Huston
# 1226273           Mel Gibson|Ray Winstone|Danny Huston
# 817230          Julia Roberts|Jamie Foxx|Anne Hathaway
# 780653    Benicio Del Toro|Anthony Hopkins|Emily Blunt
# 1130884  Leonardo DiCaprio|Emily Mortimer|Mark Ruffalo
#
#                                            main_cast_links  \
# IMDB_ID
# 433362   /name/nm0000160/|/name/nm0000353/|/name/nm0000...
# 1216492  /name/nm0010736/|/name/nm0328828/|/name/nm0004...
# 1037705  /name/nm0000243/|/name/nm0005109/|/name/nm0829...
# 1038686  /name/nm0079273/|/name/nm0000598/|/name/nm0001...
# 1244659  /name/nm0000409/|/name/nm0005392/|/name/nm0000...
# 1185416  /name/nm0068338/|/name/nm0241049/|/name/nm0001...
# 1226273  /name/nm0000154/|/name/nm0935653/|/name/nm0396...
# 817230   /name/nm0000210/|/name/nm0004937/|/name/nm0004...
# 780653   /name/nm0001125/|/name/nm0000164/|/name/nm1289...
# 1130884  /name/nm0000138/|/name/nm0607865/|/name/nm0749...
#
#                               dir_list  \
# IMDB_ID
# 433362   Michael Spierig|Peter Spierig
# 1216492                   Anand Tucker
# 1037705     Albert Hughes|Allen Hughes
# 1038686                  Scott Stewart
# 1244659                    Tom Vaughan
# 1185416            Mark Steven Johnson
# 1226273                Martin Campbell
# 817230                  Garry Marshall
# 780653                    Joe Johnston
# 1130884                Martin Scorsese
#
#                                               creator_list  \
# IMDB_ID
# 433362                       Michael Spierig|Peter Spierig
# 1216492                        Deborah Kaplan|Harry Elfont
# 1037705                                        Gary Whitta
# 1038686                         Peter Schink|Scott Stewart
# 1244659                   Robert Nelson Jacobs|Geeta Anand
# 1185416                       David Diamond|David Weissman
# 1226273  William Monahan|Andrew Bovell|Troy Kennedy-Martin
# 817230   Katherine Fugate|Katherine Fugate|Abby Kohn|Ma...
# 780653         Andrew Kevin Walker|David Self|Curt Siodmak
# 1130884                     Laeta Kalogridis|Dennis Lehane
#
#                                                genre motion_picture_rating  \
# IMDB_ID
# 433362   [Action, Fantasy, Horror, Sci-Fi, Thriller]                     R
# 1216492                            [Comedy, Romance]                    PG
# 1037705         [Action, Adventure, Drama, Thriller]                     R
# 1038686                    [Action, Fantasy, Horror]                     R
# 1244659                                        Drama                    PG
# 1185416                            [Comedy, Romance]                 PG-13
# 1226273            [Crime, Drama, Mystery, Thriller]                     R
# 817230                             [Comedy, Romance]                 PG-13
# 780653            [Drama, Fantasy, Horror, Thriller]                     R
# 1130884                          [Mystery, Thriller]                     R
#
#                          release_date  ... meta_critic_score  \
# IMDB_ID                                ...
# 433362    14 January 2010 (Singapore)  ...               NaN
# 1216492  12 February 2010 (Singapore)  ...              33.0
# 1037705     18 March 2010 (Singapore)  ...               NaN
# 1038686   21 January 2010 (Singapore)  ...              32.0
# 1244659         22 January 2010 (USA)  ...               NaN
# 1185416     25 March 2010 (Singapore)  ...              25.0
# 1226273   28 January 2010 (Singapore)  ...               NaN
# 817230   11 February 2010 (Singapore)  ...              34.0
# 780653   18 February 2010 (Singapore)  ...               NaN
# 1130884     15 April 2010 (Singapore)  ...               NaN
#
#          num_user_ratings  num_critic_ratings  \
# IMDB_ID
# 433362              301.0               291.0
# 1216492             219.0               136.0
# 1037705             588.0               331.0
# 1038686             328.0               227.0
# 1244659              67.0               129.0
# 1185416              88.0               148.0
# 1226273             271.0               262.0
# 817230              226.0               189.0
# 780653              449.0               368.0
# 1130884               1.0               509.0
#
#                                                 story_line  \
# IMDB_ID
# 433362       In a world 10 years into the future, vampi...
# 1216492      A woman who has an elaborate scheme to pro...
# 1037705      In a violent post-apocalyptic society, a d...
# 1038686      An out-of-the-way diner becomes the unlike...
# 1244659      A Portland couple have two children with P...
# 1185416      Beth is a hard working career woman whose ...
# 1226273      Thomas Craven is a detective who has spent...
# 817230       More than a dozen Angelenos navigate Valen...
# 780653       Lawrence Talbot's childhood ended the nigh...
# 1130884      It's 1954, and up-and-coming U.S. marshal ...
#
#                                                     others          Gross  \
# IMDB_ID
# 433362   {'Crazy Credits': '\nCrazy Credits\n    In lin...     51,416,464
# 1216492  {'Filming Locations:': '\nFilming Locations:\n...    25,918,920
# 1037705  {'Filming Locations:': '\nFilming Locations:\n...   157,107,755
# 1038686  {'Crazy Credits': '\nCrazy Credits\n    At the...     67,918,658
# 1244659  {'Filming Locations:': '\nFilming Locations:\n...     11,854,694
# 1185416  {'Crazy Credits': '\nCrazy Credits\n    The ca...     32,669,555
# 1226273  {'Filming Locations:': '\nFilming Locations:\n...    82,812,456
# 817230   {'Crazy Credits': '\nCrazy Credits\n    Gag re...   216,485,654
# 780653   {'Filming Locations:': '\nFilming Locations:\n...   139,789,765
# 1130884  {'Filming Locations:': '\nFilming Locations:\n...    294,804,195
#
#                Country                           Language  \
# IMDB_ID
# 433362   Australia|USA                            English
# 1216492    USA|Ireland                  English|Ukrainian
# 1037705            USA                            English
# 1038686            USA                            English
# 1244659            USA                            English
# 1185416            USA          English|Italian|Ukrainian
# 1226273         UK|USA                            English
# 817230             USA    English|Spanish|Russian|Italian
# 780653             USA  English|Romany|Romanian|Ukrainian
# 1130884            USA                     English|German
#
#                                           Production_House  \
# IMDB_ID
# 433362    Lionsgate, Australian Film Finance Corporatio...
# 1216492   Universal Pictures, Spyglass Entertainment, B...
# 1037705             Alcon Entertainment, Silver Pictures
# 1038686                          Screen Gems, Bold Films
# 1244659                  CBS Films, Double Feature Films
# 1185416   Touchstone Pictures, Krasnoff Foster Producti...
# 1226273                Warner Bros., GK Films, BBC Films
# 817230    New Line Cinema, Rice Films, Karz Entertainme...
# 780653    Universal Pictures, Relativity Media, Bluegra...
# 1130884   Paramount Pictures, Phoenix Pictures, Sikelia...
#
#         Average_popularity_score_per_movie
# IMDB_ID
# 433362                            8.318333
# 1216492                           6.195667
# 1037705                           8.769667
# 1038686                           4.450000
# 1244659                           6.396333
# 1185416                           7.131000
# 1226273                           6.716333
# 817230                           11.232000
# 780653                           15.329000
# 1130884                          10.646667
#
# [10 rows x 21 columns]

# %%
df.shape
# Out:
# (4351, 21)

# %%
df = df.drop(['main_cast_list', 'main_cast_links','dir_list','creator_list', 'meta_critic_score','story_line', 'others'], axis = 1)

# %%
df.head(3)

# %%
df.shape

# %% [markdown]
# ## Data Transformations

# %% [markdown]
# ### 1. Check for NAs/NANs

# %%
df.describe()
# Out:
#         num_ratings   avg_rating  num_user_ratings  num_critic_ratings  \
# count  4.351000e+03  4351.000000       4267.000000         4267.000000
# mean   4.943871e+04     6.466766        117.522615          132.775486
# std    1.108960e+05     0.960129        173.167208          140.513302
# min    9.000000e+00     1.500000          1.000000            1.000000
# 25%    1.779500e+03     5.900000         13.000000           29.000000
# 50%    8.299000e+03     6.600000         43.000000           77.000000
# 75%    4.256200e+04     7.100000        145.000000          192.000000
# max    1.812301e+06     9.300000        998.000000          974.000000
#
#        Average_popularity_score_per_movie
# count                         4351.000000
# mean                             3.847854
# std                              3.476414
# min                              0.000000
# 25%                              1.077167
# 50%                              2.855333
# 75%                              5.797000
# max                             21.596333

# %%
df.shape

# %% [markdown]
# #### Columns with NAs
# MPAA rating, num_user_ratings, num_critic_ratings, language, production_house

# %%
df.isnull().any()
# Out:
# Name                                  False
# num_ratings                           False
# avg_rating                            False
# genre                                 False
# motion_picture_rating                  True
# release_date                          False
# duration                               True
# num_user_ratings                       True
# num_critic_ratings                     True
# Gross                                 False
# Country                               False
# Language                               True
# Production_House                       True
# Average_popularity_score_per_movie    False
# dtype: bool

# %% [markdown]
# #### How many NAs total?
# Could be multiple NAs for a given row.

# %%
df.isnull().sum().sum()
# Out:
# 648

# %% [markdown]
# #### How many NAs per column?
# Can it be manually fixed by finding the true value? Say, for duration of a couple of movies.

# %%
df.isnull().sum(axis = 0)

# %%
df[df['duration'].isnull()]

# %% [markdown]
# This anyway has other columns as NaNs (info isn't available on IMDB anymore?),  so might as well drop the row.

# %% [markdown]
# #### If dropping all NAs?

# %%
# Lose 442 (45 rows still have NA in num_user_ratings, num_critic_ratings)
df = df.dropna(subset=['Language', 'Production_House','motion_picture_rating'])
df.shape
# Out:
# (3909, 14)

# %% [markdown]
# #### num_user_ratings and num_critic_ratings still have NAs - we will impute these later (pipelining) using median

# %%
df.isnull().any()
# Out:
# Name                                  False
# num_ratings                           False
# avg_rating                            False
# genre                                 False
# motion_picture_rating                 False
# release_date                          False
# duration                              False
# num_user_ratings                       True
# num_critic_ratings                     True
# Gross                                 False
# Country                               False
# Language                              False
# Production_House                      False
# Average_popularity_score_per_movie    False
# dtype: bool

# %%
# number of IMDB user reviews written
df['num_user_ratings'].isnull().sum()
# Out:
# 42

# %%
# metacritic rating
df['num_critic_ratings'].isnull().sum()
# Out:
# 42

# %% [markdown]
# ### 2. Add number of languages

# %%
# inspect unique values
df.Language.unique()

# %%
languages_split = df.Language.str.split(pat="|")
df['num_languages'] = languages_split.str.len()

# %%
# inspect
df.head(3)

# %%
# check NaN
df['num_languages'].isnull().values.any()

# %% [markdown]
# ### 3. Truncate 'Languages' and 'Country'

# %%
# inspect unique values
df.Country.unique()

# %%
languages_split = df.Language.str.split(pat="|").apply(lambda x: x[0])
df['Language'] = languages_split

# %%
countries_split = df.Country.str.split(pat="|").apply(lambda x: x[0])
df['Country'] = countries_split

# %%
df.head(3)

# %%
# check both columns for NaN
print(df['Language'].isnull().values.any())
print(df['Country'].isnull().values.any())

# %%
# check how many unique values of each
print(len(df.Country.unique()))
print(len(df.Language.unique()))

# %% [markdown]
# ### 4. Truncate 'Production_House'

# %%
# inspect unique values - 3697 of them, can't see all
df.Production_House.unique()

# %%
production_house_split = df.Production_House.str.split(pat=", ").apply(lambda x: x[0])
df['Production_House'] = production_house_split

# %%
# still could too unqiue of a column - 2277 unique values!
len(df.Production_House.unique())

# %% [markdown]
# ### 5. Check MPAA column and regroup
# https://simple.m.wikipedia.org/wiki/Motion_Picture_Association_of_America_film_rating_system
#
# #### **Reclassification:**
# * TV-Y, TV-7, TV-G --> G
# * TV-PG --> PG
# * TV-14 --> PG-13
# * TV-MA --> R
# * Not Rated (923!) -->
# * Unrated (143) -->

# %%
# check NaN
df['motion_picture_rating'].isnull().values.any()

# %%
# what are the unique ratings, and how many in each category?
df.groupby('motion_picture_rating').size()
# Out:
# motion_picture_rating
# G              39
# NC-17           2
# Not Rated     923
# PG            358
# PG-13         909
# R            1415
# TV-14          28
# TV-G            4
# TV-MA          33
# TV-PG          11
# TV-Y            1
# TV-Y7           1
# Unrated       143
# dtype: int64

# %%
df.loc[df['motion_picture_rating'].isin(["TV-G", "TV-Y7", "TV-Y"]), 'motion_picture_rating'] = "G"
df.loc[df['motion_picture_rating'].isin(["TV-PG"]), 'motion_picture_rating'] = "PG"
df.loc[df['motion_picture_rating'].isin(["TV-14"]), 'motion_picture_rating'] = "PG-13"
df.loc[df['motion_picture_rating'].isin(["TV-MA"]), 'motion_picture_rating'] = "R"


df.loc[df['motion_picture_rating'].isin(["Unrated"]), 'motion_picture_rating'] = "PG" # mostly documentaries
df.loc[df['motion_picture_rating'].isin(["Not Rated"]), 'motion_picture_rating'] = "PG-13"

df.groupby('motion_picture_rating').size()
# Out:
# motion_picture_rating
# G          45
# NC-17       2
# PG        512
# PG-13    1860
# R        1448
# dtype: int64

# %%
df[df['motion_picture_rating'] == "Not Rated"]
# Out:
# Empty DataFrame
# Columns: [Name, num_ratings, avg_rating, genre, motion_picture_rating, release_date, duration, num_user_ratings, num_critic_ratings, Gross, Country, Language, Production_House, Average_popularity_score_per_movie, num_languages]
# Index: []

# %%
df[df['motion_picture_rating'] == "Unrated"]
# Out:
#                                                       Name  num_ratings  \
# IMDB_ID
# 1407055                                  Violet Tendencies          540
# 1287878                                                Shi         8510
# 1470024                                Marti, dupã Crãciun         3942
# 1623008                                          The Arbor         1547
# 1562450                                 Stonewall Uprising          438
# 1282153                        O Estranho Caso de Angélica         1530
# 1522857                                           The Oath          738
# 1517177                                                  3         4709
# 1590024                    Eu cand vreau sa fluier, fluier         5719
# 1721683                                  La belle endormie          640
# 1696535                      El Bulli: Cooking in Progress         1035
# 1542852                                           Carancho         7031
# 1597089                   Phil Ochs: There But for Fortune          346
# 1319744                                   The Interrupters         3318
# 1978447                                          Ha-shoter          751
# 1288376                                         Die Fremde         4921
# 1787725  If a Tree Falls: A Story of the Earth Liberati...         2938
# 1653827                                         Boxing Gym          388
# 1699185                                  Les hommes libres         1218
# 2104994                     Steve Jobs: The Lost Interview         1636
# 2209300                                           Poklosie         3053
# 3486542                                       Mediterranea         1219
# 2634200  Don't Think I've Forgotten: Cambodia's Lost Ro...          261
# 1702429                           Eisenstein in Guanajuato         2254
# 2611390                                             Difret         1105
# 4504040                                 A Ballerina's Tale          585
# 4515684                                            Comoara         2324
# 3997238                                    Do I Sound Gay?         1658
# 3334212                                   This Isn't Funny          348
# 3478962                                            Mon roi         9142
# 4721400                                         Desde allá         2994
# 4120210                                     Valley of Love         1691
# 4085084                                           Maryland         4935
# 4899406                                           Boi Neon         2278
# 2731398                   Fifi az khoshhali zooze mikeshad          279
# 2325517                                       Almost Human         2730
# 4726636                                           Ma Loute         3498
# 4874206                                         (M)uchenik         3764
# 3908142                                     The Love Witch         9008
# 3352034                               Five Nights in Maine          577
# 3646344                                    Vergine giurata          836
# 4610244                                     The Other Side          872
# 4569240                         Un monstruo de mil cabezas          802
# 2818654                                   Rak ti Khon Kaen         3523
# 1830786                                            Rascals         2296
# 2586118                                         D'Ardennen         4114
# 4158876                                       Other People         7584
# 2531318  The Beatles: Eight Days a Week - The Touring Y...         9467
# 4451458                                     Poesía Sin Fin         3878
# 4485246                                         Danny Says          639
# 5912454                                           Blue Jay        10002
# 4331970                                  Quand on a 17 ans         4445
# 4392770                                       Always Shine         3378
# 5254640                                          Spa Night          936
# 4935480                                 Miss Sharon Jones!          480
# 5525310                                      National Bird          491
# 4381236                               The Greasy Strangler         5169
# 4630550                                  La fille inconnue         5850
# 5231812                                    Rester vertical         1798
# 4482858                                             Tikkun          359
# 5535814                                 Peter and the Farm          558
# 4400174                           À peine j'ouvre les yeux         1061
# 1439558                                           Max Rose          415
#
#          avg_rating                                              genre  \
# IMDB_ID
# 1407055         6.2                           [Comedy, Drama, Romance]
# 1287878         7.8                                              Drama
# 1470024         7.0                                   [Drama, Romance]
# 1623008         7.2                    [Documentary, Biography, Drama]
# 1562450         7.2                             [Documentary, History]
# 1282153         6.3                                   [Drama, Fantasy]
# 1522857         7.4                                        Documentary
# 1517177         6.8                           [Comedy, Drama, Romance]
# 1590024         7.2                                              Drama
# 1721683         5.7                                              Drama
# 1696535         6.4                                        Documentary
# 1542852         6.9                  [Crime, Drama, Romance, Thriller]
# 1597089         7.6           [Documentary, Biography, History, Music]
# 1319744         7.5                               [Documentary, Crime]
# 1978447         6.2                                              Drama
# 1288376         7.5                                              Drama
# 1787725         7.2  [Documentary, Biography, Crime, Drama, History...
# 1653827         7.1                                        Documentary
# 1699185         6.6                     [Drama, History, Romance, War]
# 2104994         8.1                                        Documentary
# 2209300         7.3                         [Drama, Fantasy, Thriller]
# 2190367         7.1                                  [Drama, Thriller]
# 1610516         7.0                           [Documentary, Biography]
# 1549589         5.6                                              Drama
# 1524095         7.8                           [Documentary, Biography]
# 2371824         6.8                                              Drama
# 2821088         6.1                                   [Drama, Romance]
# 2263058         7.6                                        Documentary
# 1815717         6.1                                  [Comedy, Romance]
# 5173032         6.1                         [Drama, Mystery, Thriller]
# 5883632         7.0                                   [Drama, Romance]
# 4066836         5.7                     [Comedy, Drama, Family, Sport]
# 4961380         4.8                         [Action, Horror, Thriller]
# 4058122         4.8                         [Comedy, Horror, Thriller]
# 6193424         6.6                                    [Comedy, Drama]
# 4929038         6.4                        [Adventure, Drama, Mystery]
# 5348236         6.7                                              Drama
# 3591696         4.4                                           Thriller
# 5452964         6.8                                              Drama
# 5540188         6.7                           [Crime, Drama, Thriller]
# 3319844         7.2                                        Documentary
# 6057032         7.1                                              Drama
# 5061162         7.3                                    [Comedy, Drama]
# 5157326         7.0                                              Drama
# 3409848         6.8                                              Drama
# 3185602         6.0                           [Comedy, Drama, Romance]
# 6802896         6.9                                     [Crime, Drama]
# 5827212         6.3                                           Thriller
# 1590157         5.6                                    [Comedy, Drama]
# 5701718         5.5                         [Drama, Romance, Thriller]
# 2241750         5.2                            [Drama, Romance, Sport]
# 3278224         7.4                                   [Drama, Romance]
# 6794376         6.8                           [Documentary, Biography]
# 5989220         6.5                                              Drama
# 5275866         7.2                  [Documentary, Biography, History]
# 4623812         7.0                                              Drama
# 6069126         5.9                                              Drama
# 3555036         6.5                                    [Action, Drama]
# 7363336         7.3                                        Documentary
# 6101602         6.4                         [Drama, Mystery, Thriller]
# 2773246         6.6                           [Documentary, Biography]
# 6217664         7.8           [Documentary, Biography, History, Music]
# 6532374         6.3                    [Comedy, Drama, Romance, Sport]
# 5338644         5.3                            [Comedy, Drama, Sci-Fi]
# 1398949         7.1                                        Documentary
# 2301592         7.5                        [Biography, Drama, Fantasy]
# 2371834         6.7                                              Drama
# 2247432         6.4                           [Crime, Drama, Thriller]
# 1783422         7.1                                  [Drama, Thriller]
# 2914838         6.1                                    [Comedy, Drama]
# 3576084         7.3                                    [Comedy, Drama]
# 2141751         6.4                          [Drama, Musical, Romance]
# 1745787         7.1                                     [Crime, Drama]
# 3060492         7.2                                              Drama
# 1403214         7.1                                              Drama
# 2531282         6.8                                        Documentary
# 2435458         5.4                                    [Comedy, Drama]
# 1362518         7.2                    [Documentary, Biography, Music]
# 2437548         5.2                           [Comedy, Drama, Romance]
# 2359381         4.7                                    [Comedy, Drama]
# 2368635         6.1                          [Drama, Fantasy, Romance]
# 2328922         5.5                                              Drama
# 3204144         6.6                                  [Comedy, Romance]
# 1982113         7.2                                        Documentary
# 2199543         6.1                                   [Drama, Romance]
# 3218580         6.2                 [Crime, Horror, Romance, Thriller]
# 2343158         6.3                                              Drama
# 1590013         6.1                                 [Biography, Drama]
# 2210834         6.1                       [Biography, Drama, Thriller]
# 3163304         7.0                           [Comedy, Drama, Romance]
# 2062961         6.7                                        Documentary
# 1541666         7.1                                        Documentary
# 2991092         6.9                  [Crime, Drama, Romance, Thriller]
# 3526706         6.3                                    [Comedy, Drama]
# 3455740         5.7                                 [Biography, Drama]
# 1766085         6.7                       [Documentary, Comedy, Drama]
# 3400980         6.3                                   [Comedy, Horror]
# 3186946         6.7                                   [Drama, Romance]
# 4145178         8.2                           [Documentary, Biography]
# 3505712         5.7                                              Drama
# 4074512         6.8                                   [Drama, Fantasy]
# 3486542         6.5                                              Drama
# 2634200         7.8                               [Documentary, Music]
# 1702429         6.3                [Biography, Comedy, Drama, Romance]
# 2611390         6.8                 [Biography, Crime, Drama, History]
# 4504040         6.4                                        Documentary
# 4515684         6.7                                             Comedy
# 3997238         5.6                                        Documentary
# 3334212         6.3                           [Comedy, Drama, Romance]
# 3478962         7.1                                   [Drama, Romance]
# 4721400         6.6                                   [Drama, Romance]
# 4120210         5.9                                              Drama
# 4085084         6.2                                  [Drama, Thriller]
# 4899406         6.8                                              Drama
# 2731398         7.7                                        Documentary
# 2325517         4.6                         [Horror, Sci-Fi, Thriller]
# 4726636         6.0                                             Comedy
# 4874206         6.9                                              Drama
# 3908142         6.2                                [Romance, Thriller]
# 3352034         4.5                                              Drama
# 3646344         6.3                                              Drama
# 4610244         6.9                               [Documentary, Drama]
# 4569240         6.5                                  [Drama, Thriller]
# 2818654         6.8                                   [Drama, Fantasy]
# 1830786         2.9                     [Action, Comedy, Crime, Drama]
# 2586118         6.8                                              Drama
# 4158876         6.7                                    [Comedy, Drama]
# 2531318         7.8                               [Documentary, Music]
# 4451458         7.6                        [Biography, Drama, Fantasy]
# 4485246         6.7  [Documentary, Animation, Biography, History, M...
# 5912454         7.3                                              Drama
# 4331970         7.2                                   [Drama, Romance]
# 4392770         5.6                                  [Drama, Thriller]
# 5254640         5.9                                              Drama
# 4935480         7.2                               [Documentary, Music]
# 5525310         7.1                                        Documentary
# 4381236         5.7                                   [Comedy, Horror]
# 4630550         6.5                  [Crime, Drama, Mystery, Thriller]
# 5231812         6.1                                    [Comedy, Drama]
# 4482858         6.5                                   [Drama, Mystery]
# 5535814         7.2                                        Documentary
# 4400174         6.8                                              Drama
# 1439558         6.3                                              Drama
#
#         motion_picture_rating                   release_date  duration  \
# IMDB_ID
# 1407055               Unrated            24 April 2010 (USA)  1h 39min
# 1287878               Unrated      13 May 2010 (South Korea)  2h 19min
# 1470024               Unrated    17 September 2010 (Romania)  1h 39min
# 1623008               Unrated            25 April 2010 (USA)  1h 34min
# 1562450               Unrated             16 June 2010 (USA)  1h 20min
# 1282153               Unrated         16 March 2011 (France)  1h 37min
# 1522857               Unrated             January 2010 (USA)  1h 30min
# 1517177               Unrated     23 December 2010 (Germany)  1h 59min
# 1590024               Unrated        26 March 2010 (Romania)  1h 34min
# 1721683               Unrated      TV Movie 3 September 2010  1h 22min
# 1696535               Unrated    15 September 2011 (Germany)  1h 48min
# 1542852               Unrated         6 May 2010 (Argentina)  1h 47min
# 1597089               Unrated           5 January 2011 (USA)  1h 36min
# 1319744               Unrated            12 August 2011 (UK)   2h 5min
# 1978447               Unrated                  2011 (Israel)  1h 45min
# 1288376               Unrated        11 March 2010 (Germany)  1h 59min
# 1787725               Unrated             January 2011 (USA)  1h 25min
# 1653827               Unrated          9 March 2011 (France)  1h 31min
# 1699185               Unrated     28 September 2011 (France)  1h 39min
# 2104994               Unrated     6 September 2012 (Germany)  1h 10min
# 2209300               Unrated       9 November 2012 (Poland)  1h 47min
# 1590013                            1.239333              1
# 2210834                            4.109000              1
# 3163304                            0.866667              2
# 2062961                            0.000000              1
# 1541666                            0.000000              1
# 2991092                            0.866667              3
# 3526706                            0.860000              2
# 3455740                            4.329667              1
# 1766085                            1.079667              1
# 3400980                            1.432667              1
# 3186946                            0.600000              3
# 4145178                            3.133000              1
# 3505712                            3.044667              1
# 4074512                            0.400000              2
# 3486542                            0.660000              4
# 2634200                            0.200000              3
# 1702429                            1.180000              2
# 2611390                            0.400000              1
# 4504040                            0.200000              1
# 4515684                            0.400000              1
# 3997238                            1.281000              2
# 3334212                            1.053333              1
# 3478962                            3.455667              1
# 4721400                            1.053333              1
# 4120210                            2.878333              2
# 4085084                            8.735000              1
# 4899406                            0.792000              1
# 2731398                            0.000000              1
# 2325517                            0.600000              1
# 4726636                            3.091667              2
# 4874206                            2.768667              1
# 3908142                            0.791667              1
# 3352034                            3.252667              1
# 3646344                            1.134667              2
# 4610244                            0.200000              1
# 4569240                            0.600000              1
# 2818654                            0.400000              2
# 1830786                            1.669000              4
# 2586118                            2.851000              3
# 4158876                            2.968667              1
# 2531318                            0.856333              1
# 4451458                            0.666667              3
# 4485246                            1.037333              1
# 5912454                            4.158000              1
# 4331970                            0.766667              2
# 4392770                            1.909667              1
# 5254640                            0.200000              3
# 4935480                            0.460000              1
# 5525310                            0.000000              2
# 4381236                            0.600000              1
# 4630550                            0.754667              1
# 5231812                            0.431333              1
# 4482858                            0.600000              2
# 5535814                            0.000000              1
# 4400174                            0.866667              2
# 1439558                            2.923000              1

# %%
# check NaN after transforming
df['motion_picture_rating'].isnull().values.any()
# Out:
# False

# %% [markdown]
# ### 6. Convert 'duration' column to time in minutes (integer)

# %%
def check_time(time):
    if len(time) == 1:
        if "h" in time[0]:
            new_time = 60*int(re.sub("\D", "", time[0]))
        else:
            new_time = int(re.sub("\D", "", time[0]))
    else:
        new_time = 60*int(re.sub("\D", "", time[0])) + int(re.sub("\D", "", time[1]))
    return new_time

test1 = df.duration.str.split(" ")
test2 = test1.apply(lambda x: check_time(x))

df['duration'] = test2

# %%
# check unique values
print(df.duration.unique())
# Out:
# [ 98 100 118 106  91 117 125 103 138 107 128  94 101 108 165 115  92 132
#  104 113  93 110 111  88  97  87 124  90  95 105 140 112 116 146 109  81
#   84 148 102 114  80  99 163  79 135  82  96 120 133  44 123  86 122 129
#  130 334  85 121 134 142 119  89  83 139 141 131 136 154  63  75 180 272
#  157 155 143 127 150 137 126 164 158  76 145  70  78 144 147 172 169 151
#   40 152  77 149 186  59 153 161 160 220  71 167  74 188 201 183 226 166
#   68  69 185 168 159 173 162  60 156 270 187  72  39 176  73 174 171 190
#  170  46  66]

# %%
## check for NaNs after transforming
df['duration'].isnull().values.any()
# Out:
# False

# %% [markdown]
# ### 7. Expanding 'genre' to one-hot columns

# %%
type(df['genre'].iloc[0]) # Need to convert string representation of list to an actual Python list to accumulate as et later

# %%
# check unique genre lists
unique_genre_lists = df['genre'].unique()
print(unique_genre_lists)

# %%
def convert_to_list(x):
    if "[" in x:
        x = re.sub("[\[\]]", "", x)
        x = x.split(", ")
    else:
        x = x.split(" ") # split by non-existent delimiter
    return x

# %%
# get all unique genres available
genre_lists = df.genre.apply(lambda x: convert_to_list(x))
df.genre = genre_lists

# temp = genre_lists.tolist()
# flattened =  [y for x in temp for y in x]
# print(set(flattened))

# %%
type(df['genre'].iloc[0])

# %%
# add 23 new one-hot columns
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
df = df.join(pd.DataFrame(mlb.fit_transform(df.pop('genre')),
                          columns=mlb.classes_,
                          index=df.index))

# %%
df.head(3)
# Out:
#                     Name  num_ratings  avg_rating motion_picture_rating  \
# IMDB_ID
# 433362       Daybreakers       116014         6.5                     R
# 1216492        Leap Year        85208         6.5                    PG
# 1037705  The Book of Eli       268523         6.9                     R
#
#                          release_date  duration  num_user_ratings  \
# IMDB_ID
# 433362    14 January 2010 (Singapore)        98             301.0
# 1216492  12 February 2010 (Singapore)       100             219.0
# 1037705     18 March 2010 (Singapore)       118             588.0
#
#          num_critic_ratings          Gross    Country   ...    Musical  \
# IMDB_ID                                                 ...
# 433362                291.0     51,416,464  Australia   ...          0
# 1216492               136.0    25,918,920         USA   ...          0
# 1037705               331.0   157,107,755         USA   ...          0
#
#         Mystery  News  Romance  Sci-Fi  Short  Sport  Thriller  War  Western
# IMDB_ID
# 433362        0     0        0       1      0      0         1    0        0
# 1216492       0     0        1       0      0      0         0    0        0
# 1037705       0     0        0       0      0      0         1    0        0
#
# [3 rows x 37 columns]

# %%
# check for NaNs after transforming in all genre columns
df.shape
# Out:
# (3867, 37)

# %% [markdown]
# ### 8. Release date to datetime and release location as a separate column

# %% [markdown]
# ### 9. Cleaning up 'Gross'
# Standardize currency, hard-code 3-digit movies, convert string to int/float

# %%
type(df['Gross'].iloc[0])

# %%
pd.set_option('display.max_row', 4000)
#df.Gross

# %%
# look for values which have alphabetic characters in them => not in USD and  has to be converted
df[df.Gross.str.contains(pat = "[a-zA-Z]")]

# %%
# remove extra whitespaces, commas:
df['Gross'] = df.Gross.apply(lambda x: re.sub("[,\s]", "", x))
df[df.Gross.str.contains(pat = "[a-zA-Z]")]
# Out:
#                                     Name  num_ratings  avg_rating  \
# IMDB_ID
# 2082197                           Barfi!        68152         8.1
# 2377938                  Special Chabbis        44672         8.0
# 6522546                           Spyder         7799         6.8
# 1512888                 Ayirathil Oruvan         2724         7.7
# 6148156                     Vikram Vedha        17906         8.7
# 2309600                         Singam 2         4966         6.3
# 5867800                            Aruvi         8034         8.8
# 5451690                   American Satan         2474         5.5
# 5956100                  Tiger Zinda Hai        18396         6.1
# 5460068                  Emo the Musical          795         6.2
# 6878378                          Vivegam         9840         5.9
# 3638644                       Seto Surya          362         7.0
# 5440700                            Theri        11077         7.2
# 1965272                       Velayudham         9750         6.4
# 1821478                         Kaavalan         4017         6.9
# 6485666                           Mersal        21747         8.0
# 3563156                           Anjaan         3414         4.9
# 6734984              Duvvada Jagannadham         2451         5.5
# 3555036                           Legend         1554         6.5
# 3802668         Govindudu Andari Vaadele         1607         5.7
# 2204243                         Baadshah         3661         6.5
# 6027478                           Dhruva         4629         8.0
# 5457772                       Sarrainodu         3137         6.4
# 5297256                      Pulimurugan         6133         7.0
# 1661031                     Brindaavanam         3195         7.2
# 6980546                  Bharat Ane Nenu        13039         8.0
# 7098658                            Raazi        16995         7.8
# 403935                    Action Jackson         2812         3.3
# 3417422                         Drishyam        23724         8.8
# 2359810                       Raanjhanaa        26543         7.6
# 3848892                             Baby        47710         8.0
# 2585562                            Pizza         5450         8.1
# 2877108                    Soodhu Kavvum         7153         8.4
# 3569782                      Jigarthanda         8325         8.4
# 1851988                               Ko         4481         7.8
# 5098128                 Nannaku Prematho         7937         7.7
# 4727512                      Srimanthudu         9548         7.6
# 2304655                     Gabbar Singh         5234         7.1
# 3142764                      Race Gurram         7531         7.2
# 1729637                        Bodyguard        20075         4.6
# 1890493                      Oosaravelli         2946         6.6
# 1992138                            Force         6290         6.4
# 3495026                              Fan        38733         7.1
# 2555958                         Arrambam         8017         7.2
# 4258292                 Yennai Arindhaal         7193         7.3
# 5178278                          Vedalam         5139         6.3
# 3320578                           Veeram         6312         6.6
# 1891755                          Billa 2         9798         6.3
# 1655607                           Singam         4581         6.7
# 2362778  Saheb Biwi Aur Gangster Returns         3491         6.8
# 2106537       Matru ki Bijlee ka Mandola         5727         5.7
# 1375789                           Race 2        13933         5.3
#
#                                              genre motion_picture_rating  \
# IMDB_ID
# 2082197                   [Comedy, Drama, Romance]                 PG-13
# 2377938                   [Crime, Drama, Thriller]                 PG-13
# 6522546                         [Action, Thriller]                 PG-13
# 1512888               [Action, Adventure, Fantasy]                 PG-13
# 6148156                  [Action, Crime, Thriller]                 PG-13
# 2309600                         [Action, Thriller]                 PG-13
# 5867800                                      Drama                 PG-13
# 5451690                   [Drama, Music, Thriller]                     R
# 5956100              [Action, Adventure, Thriller]                 PG-13
# 5460068                   [Comedy, Music, Musical]                 PG-13
# 6878378                         [Action, Thriller]                 PG-13
# 3638644                         [Adventure, Drama]                    PG
# 5440700                            [Action, Drama]                 PG-13
# 1965272                        [Action, Adventure]                 PG-13
# 1821478                   [Action, Drama, Romance]                 PG-13
# 6485666                         [Action, Thriller]                 PG-13
# 3563156                  [Action, Crime, Thriller]                 PG-13
# 6734984                           [Action, Comedy]                 PG-13
# 3555036                            [Action, Drama]                    PG
# 3802668                            [Action, Drama]                 PG-13
# 2204243                           [Action, Comedy]                 PG-13
# 6027478                         [Action, Thriller]                 PG-13
# 5457772                            [Action, Drama]                 PG-13
# 5297256                                     Action                 PG-13
# 1661031  [Action, Comedy, Drama, Musical, Romance]                 PG-13
# 6980546                            [Action, Drama]                 PG-13
# 7098658                  [Action, Drama, Thriller]                 PG-13
# 403935                          [Action, Thriller]                 PG-13
# 3417422                   [Crime, Drama, Thriller]                 PG-13
# 2359810                           [Drama, Romance]                 PG-13
# 3848892                         [Action, Thriller]                 PG-13
# 2585562                         [Horror, Thriller]                 PG-13
# 2555958        31 October 2013 (India)       157              36.0
# 4258292        5 February 2015 (India)       168              41.0
# 5178278       10 November 2015 (India)       148              38.0
# 3320578        10 January 2014 (India)       161              39.0
# 1891755       13 July 2012 (Singapore)       129             128.0
# 1655607            28 May 2010 (India)       160              14.0
# 2362778           8 March 2013 (India)       142              15.0
# 2106537        11 January 2013 (India)       151              42.0
# 1375789        25 January 2013 (India)       150              51.0
#
#          num_critic_ratings            Gross    Country   Language  \
# IMDB_ID
# 2082197                62.0    INR1030300000      India      Hindi
# 2377938                30.0     INR810000000      India      Hindi
# 6522546                13.0           INR124      India     Telugu
# 1512888                 3.0     INR850000000      India      Tamil
# 6148156                16.0     INR400000000      India    English
# 2309600                 4.0    INR1286960000      India      Tamil
# 5867800                18.0     INR350000000      India      Tamil
# 5451690                10.0            VND74        USA    English
# 5956100                32.0    INR5650100000      India      Hindi
# 5460068                34.0      AUD56400000  Australia    English
# 6878378                20.0     INR120000000      India      Tamil
# 3638644                29.0      NPR20000000      Nepal     Nepali
# 5440700                12.0    INR1500000000      India      Tamil
# 1965272                 7.0     INR480000000      India      Tamil
# 1821478                 2.0     INR450000000      India      Tamil
# 6485666                13.0    INR2540000000      India      Tamil
# 3563156                 7.0     INR950000000      India      Tamil
# 6734984                 5.0           INR157      India     Telugu
# 3555036                 5.0     INR400400000      India     Telugu
# 3802668                 6.0     INR416500000      India     Telugu
# 2204243                 4.0     INR384000000      India     Telugu
# 6027478                 7.0     INR890600000      India     Telugu
# 5457772                 6.0    INR1270600000      India      Hindi
# 5297256                 4.0    INR1520000000      India  Malayalam
# 1661031                 3.0     INR300100000      India     Telugu
# 6980546                21.0           INR206      India     Telugu
# 7098658                31.0  INR207000000000      India      Hindi
# 403935                 13.0     INR888717500      India      Hindi
# 3417422                10.0     INR750000000      India  Malayalam
# 2359810                22.0    INR1000000000      India      Hindi
# 3848892                25.0    INR1429900000      India      Hindi
# 2585562                10.0     INR180000000      India      Tamil
# 2877108                 8.0     INR500000000      India      Tamil
# 3569782                20.0     INR350000000      India      Tamil
# 1851988                 2.0     INR543400000      India      Tamil
# 5098128                 8.0     INR870200000      India     Telugu
# 4727512                 5.0    INR1445500000      India     Telugu
# 2304655                10.0      INR98000000      India     Telugu
# 3142764                19.0           INR130      India     Telugu
# 1729637                24.0    INR2300000000      India      Hindi
# 1890493                 2.0     INR270600000      India     Telugu
# 1992138                26.0     INR260500000      India      Hindi
# 3495026                57.0    INR1880000000      India      Hindi
# 2555958                 5.0    INR1350000000      India      Tamil
# 4258292                 8.0    INR1060000000      India      Tamil
# 5178278                11.0    INR1211570000      India      Tamil
# 3320578                 3.0    INR1300000000      India      Tamil
# 1891755                 5.0      INR80000000      India      Tamil
# 1655607                 2.0     INR750000000      India      Tamil
# 2362778                13.0     INR232700000      India      Hindi
# 2106537                20.0     INR466500000      India      Hindi
# 1375789                23.0    INR1843800000      India      Hindi
#
#                         Production_House  Average_popularity_score_per_movie  \
# IMDB_ID
# 2082197              UTV Motion Pictures                            2.915667
# 3320578              2
# 1891755              2
# 1655607              3
# 2362778              1
# 2106537              2
# 1375789              1

# %%
# add 7 trailing zeros for these 4:
# 6980546                 INR 206 Bharat Ane Nenu
# 3142764                 INR 130 Race Gurram
# 6734984                INR 157 Duvvada Jagannadham
# 6522546                INR 124 Spyder

gross_truncated = ["INR206", "INR130","INR157","INR124"]

df['Gross'] = df.Gross.apply(lambda x: x + "0000000" if x in gross_truncated else x)

# %%
# for American Satan - VND 74 cumulative worldwide gross - change to USD $226,232
# https://www.the-numbers.com/movie/American-Satan#tab=international
df.at[5451690, 'Gross'] = "226232"

# %%
# Raazi - incorrectly entered as 2070 crores gross on IMDB
df.at[7098658, 'Gross'] = "2070000000"

# %%
from currency_converter import CurrencyConverter
c = CurrencyConverter()

def convert_currency(x):
    if re.search('[a-zA-Z£]', x) == None:
        return float(x)
    
    split_gross = re.split('(\d+)',x)
    
    # GBP
    if(split_gross[0] == "£"):
        return (c.convert(float(split_gross[1]), 'GBP','USD'))
    
    # NPR isn't supported CurrencyConverter - hard code
    if(split_gross[0]  == "NPR"):
        return (float(split_gross[1])*0.0090)
    
    return (c.convert(float(split_gross[1]), split_gross[0],'USD'))


df['Gross'] = df['Gross'].apply(lambda x : convert_currency(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1239023bc9ff> in <module>
#      19
#      20
# ---> 21 df['Gross'] = df['Gross'].apply(lambda x : convert_currency(x))
#
# ~/anaconda3/envs/BT5153/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-46-1239023bc9ff> in <lambda>(x)
#      19
#      20
# ---> 21 df['Gross'] = df['Gross'].apply(lambda x : convert_currency(x))
#
# <ipython-input-46-1239023bc9ff> in convert_currency(x)
#       3
#       4 def convert_currency(x):
# ----> 5     if re.search('[a-zA-Z£]', x) == None:
#       6         return float(x)
#       7
#
# ~/anaconda3/envs/BT5153/lib/python3.7/re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df.head(5)

# %%
# check NaN
df['Gross'].isnull().values.any()

# %%
df['Gross'].describe()
# Out:
# count    3.867000e+03
# mean     6.237718e+07
# std      1.747515e+08
# min      0.000000e+00
# 25%      8.006500e+04
# 50%      1.428647e+06
# 75%      3.477335e+07
# max      2.940555e+09
# Name: Gross, dtype: float64

# %%
#### Adjust gross for inflation based on the year - need inputs from Karthik for this:
def adjust_for_inflation(gross, release_date):
    if release_date.year == 2010:
        return(gross*1.152)
    elif release_date.year == 2011: 
        return(gross*1.124)
    elif release_date.year == 2012:
        return(gross*1.101)
    elif release_date.year == 2013:
        return(gross*1.087)
    elif release_date.year == 2014:
        return(gross*1.086)
    elif release_date.year == 2015:
        return(gross*1.068)
    elif release_date.year == 2016:
        return(gross*1.053)
    elif release_date.year == 2017:
        return(gross*1.032)
    else # 2018 => just return x itself
        return gross
df['gross'] = df.apply(lambda x: adjust_for_inflation(x['gross'], x['release_date']), axis=1)

# %% [markdown]
# ### If dividing into equal revenue ranges (instead of quintiles)

# %%
# def find_revenue_range(x):
#     if  0 <= x <= 588111000:
#         return 0
#     elif 588111001 <= x <= 1176222000:
#         return 1
#     elif 1176222000 <= x <= 1764333003:
#         return 2
#     elif 1764333003 <= x <= 2352444004:
#         return 3
#     else:
#         return 4
    
        
# df['gross_equal_range'] = df['Gross'].apply(lambda x: find_revenue_range(x))

# %%
# df[df['gross_equal_range'] == 3]
# Out:
#                                                Name  num_ratings  avg_rating  \
# IMDB_ID
# 2488496  Star Wars: Episode VII - The Force Awakens       775868         8.0
# 4154756                      Avengers: Infinity War       609049         8.5
#
#                                         genre motion_picture_rating  \
# IMDB_ID
# 2488496  [Action, Adventure, Fantasy, Sci-Fi]                 PG-13
# 4154756           [Action, Adventure, Sci-Fi]                 PG-13
#
#                          release_date  duration  num_user_ratings  \
# IMDB_ID
# 2488496  17 December 2015 (Singapore)       136               4.0
# 4154756     25 April 2018 (Singapore)       149               3.0
#
#          num_critic_ratings         Gross Country Language Production_House  \
# IMDB_ID
# 2488496               869.0  2.068224e+09     USA  English        Lucasfilm
# 4154756               560.0  2.048710e+09     USA  English   Marvel Studios
#
#          Average_popularity_score_per_movie  num_languages  gross_equal_range
# IMDB_ID
# 2488496                            4.859333              1                  3
# 4154756                           15.181667              1                  3

# %% [markdown]
# ## Categorize movies by gross revenue quintile
# Split movies into 5 groups by revenue, and add (one-hot?) columns for classification.

# %%
print(list(df.columns.values))
print(df.shape)

# %%
df.head(5)

# %% [markdown]
# #### Divide into quintiles based on gross revenue
# This divides into 5 balanced classes.
# *** Dividing into 5 based on manually selected ranges results in a very high accuracy ~97%, because it is highly imbalanced - even easiest prediction of majority class can result in this accuracy.  **

# %%
ret_value = pd.qcut(df['Gross'], 5, labels=["very low", "low", "medium", "high", "very high"], retbins = True)

# %% [markdown]
# #### Check bucket values

# %%
df['gross_category'] = ret_value[0]
ret_value[1]
# low ends at 3.782940e+05, medium ends at 5.823487e+06, high ends at 6.337276e+07
# Out:
# array([0.00000000e+00, 4.64560000e+04, 3.78894000e+05, 5.83402240e+06,
#        6.34464402e+07, 2.94055455e+09])

# %%
df.groupby('gross_category').size()

# %%
df_sorted = df.sort_values(['Gross','gross_category'])

# %% [markdown]
# #### This prints the whole dataframe (all ~3k rows)!

# %%
#df_sorted

# %% [markdown]
# ## Basic Classification Model - Logistic Regression

# %% [markdown]
# ### Join df with YouTube features, Sentiment features

# %%
df_cleaned = df.copy()

# %%
df_cleaned.head(5)
# Out:
#                            Name  num_ratings  avg_rating  \
# IMDB_ID
# 433362              Daybreakers       116014         6.5
# 1216492               Leap Year        85208         6.5
# 1037705         The Book of Eli       268523         6.9
# 1038686                  Legion        91364         5.2
# 1244659  Extraordinary Measures        15595         6.5
#
#                                                genre motion_picture_rating  \
# IMDB_ID
# 433362   [Action, Fantasy, Horror, Sci-Fi, Thriller]                     R
# 1216492                            [Comedy, Romance]                    PG
# 1037705         [Action, Adventure, Drama, Thriller]                     R
# 1038686                    [Action, Fantasy, Horror]                     R
# 1244659                                        Drama                    PG
#
#                          release_date  duration  num_user_ratings  \
# IMDB_ID
# 433362    14 January 2010 (Singapore)        98             301.0
# 1216492  12 February 2010 (Singapore)       100             219.0
# 1037705     18 March 2010 (Singapore)       118             588.0
# 1038686   21 January 2010 (Singapore)       100             328.0
# 1244659         22 January 2010 (USA)       106              67.0
#
#          num_critic_ratings        Gross    Country Language  \
# IMDB_ID
# 433362                291.0   51416464.0  Australia  English
# 1216492               136.0   25918920.0        USA  English
# 1037705               331.0  157107755.0        USA  English
# 1038686               227.0   67918658.0        USA  English
# 1244659               129.0   11854694.0        USA  English
#
#              Production_House  Average_popularity_score_per_movie  \
# IMDB_ID
# 433362              Lionsgate                            8.318333
# 1216492    Universal Pictures                            6.195667
# 1037705   Alcon Entertainment                            8.769667
# 1038686           Screen Gems                            4.450000
# 1244659             CBS Films                            6.396333
#
#          num_languages  gross_equal_range gross_category
# IMDB_ID
# 433362               1                  0           high
# 1216492              2                  0           high
# 1037705              1                  0      very high
# 1038686              1                  0      very high
# 1244659              1                  0           high

# %%
# read from YouTube excel file here and join the 2 dataframes for columns - viewCount,  likeCount, dislikeCount, commentCount

# %%
# read from sentiment features

# %% [markdown]
# ### Dealing with categorical features
# Inspect non-numeric columns:
#
# * Country                                 object -- 61 unique - categorize as top 5 vs. others
# * Language                                object -- 77 unique - categorize as top 5 vs. others
# * Production_House                        object -- ~2000+ unique - categorize as top 5 vs. othersCheck
# * motion_picture_rating                   object -- only 5 groups
# * Name                                    object -- drop, too unique, unless using to derive a text-based feature
# * release_date                            object -- drop, can be used to extract weekend/not later

# %%
df_cleaned.dtypes

# %% [markdown]
# #### Check production house split

# %%
df_cleaned['Production_House'].dtypes

# %%
df_cleaned['Production_House'].head(5)

# %%
# could do top 5 vs others
df_cleaned.groupby('Production_House').size().sort_values(ascending = False).head(20)

# %%
top_production = list(df_cleaned.groupby('Production_House').size().sort_values(ascending = False).head(5).index)

df_cleaned['Production_House'] = df_cleaned.Production_House.apply(lambda x: x if x in top_production
                                         else "Other")

# %%
df_cleaned.groupby('Production_House').size().sort_values(ascending = False)

# %% [markdown]
# #### Check language split

# %%
df_cleaned.groupby('Language').size().sort_values(ascending = False).head(20) # could do English, French, Hindi, Spanish, Mandarin vs. others

# %%
top_language = list(df_cleaned.groupby('Language').size().sort_values(ascending = False).head(5).index)

df_cleaned['Language'] = df_cleaned.Language.apply(lambda x: x if x in top_language
                                         else "Other")

# %%
df_cleaned.groupby('Language').size().sort_values(ascending = False)

# %% [markdown]
# #### Check country split

# %%
df_cleaned.groupby('Country').size().sort_values(ascending = False).head(20) # could do USA, UK, France, India, Canada, China vs. others

# %%
top_countries = list(df_cleaned.groupby('Country').size().sort_values(ascending = False).head(5).index)

df_cleaned['Country'] = df_cleaned.Country.apply(lambda x: x if x in top_countries
                                         else "Other")

# %%
df_cleaned.groupby('Country').size().sort_values(ascending = False)

# %% [markdown]
# ### One-Hot Encoding
# For categorical features, and the gross_category label.

# %%
X = df_cleaned.drop(['gross_category', 'Gross', 'release_date', 'Name'], axis=1) 
# drop is NOT in-place by default, doesn't affect original DF

y = df_cleaned['gross_category'].copy()

# %%
X.dtypes
# Out:
# num_ratings                             int64
# avg_rating                            float64
# genre                                  object
# motion_picture_rating                  object
# duration                                int64
# num_user_ratings                      float64
# num_critic_ratings                    float64
# Country                                object
# Language                               object
# Production_House                       object
# Average_popularity_score_per_movie    float64
# num_languages                           int64
# gross_equal_range                       int64
# dtype: object

# %%
#categorical_cols = ["motion_picture_rating", "Country", "Language",  "Production_House"]
X_dummies = pd.get_dummies(X)

# %%
X_dummies.shape

# %%
X_dummies.head(5)

# %%
le = preprocessing.LabelEncoder()
le.fit(y)
# Out:
# LabelEncoder()

# %%
list(le.classes_)

# %%
y_encoded = le.transform(y) 
#y_encoded = y

# %% [markdown]
# ### Split data - train, test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_encoded, random_state=1)

# %%
imputer = SimpleImputer()
scaler = StandardScaler()
lr = LogisticRegression(multi_class = "multinomial", solver = 'newton-cg', max_iter = 3000)

pipe = Pipeline([('imputer', imputer),
                 ('scaler', scaler), 
                 ('lr', lr)])


pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('lr', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=3000, multi_class='multinomial',
#           n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
pipe.named_steps.keys()
# Out:
# dict_keys(['imputer', 'scaler', 'lr'])

# %%
# for any continuous parameters, specify a distribution instead of a list of options
param_grid = {}
param_grid['imputer__strategy'] = ["mean", "median"]
param_grid['scaler__with_mean'] = [True, False]
param_grid['scaler__with_std'] = [True, False]
param_grid['lr__C'] = [1, 0.75, 0.5] # smaller specifies stronger regularization
param_grid
# Out:
# {'imputer__strategy': ['mean', 'median'],
#  'scaler__with_mean': [True, False],
#  'scaler__with_std': [True, False],
#  'lr__C': [1, 0.75, 0.5]}

# %%
# additional parameters are n_iter (number of searches) and random_state
rand = RandomizedSearchCV(pipe, param_grid, cv=5, scoring='accuracy', n_iter=5, random_state=1)

# %%
# time the randomized search
# %time rand.fit(X_train, y_train)
# Out:
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# CPU times: user 14min 32s, sys: 5.54 s, total: 14min 37s
# Wall time: 7min 27s
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/scipy/optimize/linesearch.py:422: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /Users/spatika/anaconda3/envs/BT5153/lib/python3.7/site-packages/sklearn/utils/optimize.py:195: UserWarning: Line Search failed
#   warnings.warn('Line Search failed')
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('lr', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_interce...y='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False))]),
#           fit_params=None, iid='warn', n_iter=5, n_jobs=None,
#           param_distributions={'imputer__strategy': ['mean', 'median'], 'scaler__with_mean': [True, False], 'scaler__with_std': [True, False], 'lr__C': [1, 0.75, 0.5]},
#           pre_dispatch='2*n_jobs', random_state=1, refit=True,
#           return_train_score='warn', scoring='accuracy', verbose=0)

# %%
print(rand.best_score_) # hold-out set
print(rand.best_params_)
# print the best model found by RandomizedSearchCV
print(rand.best_estimator_)
# Out:
# 0.5131034482758621
# {'scaler__with_std': False, 'scaler__with_mean': True, 'lr__C': 1, 'imputer__strategy': 'median'}
# Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan,
#        strategy='median', verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=False)), ('lr', LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=3000, multi_class='multinomial',
#           n_jobs=None, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
# predictions on train and test data with best estimator
y_trainpred0 = rand.predict(X_train)
y_pred0 = rand.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred0))
#print(metrics.f1_score(y_test, y_pred0, average='macro'))
# Out:
# 0.5222337125129266
# 0.5205962928208976

# %%
# train set
print(metrics.accuracy_score(y_train, y_trainpred0))
#print(metrics.f1_score(y_train, y_trainpred0, average='macro'))
# Out:
# 0.6610344827586206
# 0.6604624669319147

# %%
# interpretation - none of these work?
#lr.summary()
# lr.intercept
lr.coef_
# Out:
# array([[ 1.08828396, -0.16609268,  0.04878577, ...,  0.16808627,
#          0.1417818 , -0.18231989],
#        [-1.14826968,  0.13146162, -0.2558423 , ..., -0.29465784,
#          0.22114469,  0.12376476],
#        [-2.15067419,  0.28179708, -0.18237579, ...,  0.15799099,
#         -0.57826512,  0.12815282],
#        [ 2.5991521 , -0.22380201,  0.88739497, ...,  0.2120307 ,
#          0.22211297, -0.39524249],
#        [-0.3884922 , -0.02336401, -0.49796265, ..., -0.24345013,
#         -0.00677433,  0.3256448 ]])

# %%
# print("Train accuracy: ", pipe.score(X_train, y_train))
# print("Test accuracy: ", pipe.score(X_test, y_test))
# Out:
# Train accuracy:  0.71
# Test accuracy:  0.5056876938986556

# %% [markdown]
# ### k-NN Classification

# %%
knn = KNeighborsClassifier()
pipe_knn = Pipeline([('imputer', imputer),
                 ('scaler', scaler), 
                 ('knn', knn)])
# pipeline steps are automatically assigned names by make_pipeline

# %%
param_grid = {}
param_grid['imputer__strategy'] = ["mean", "median"]
param_grid['scaler__with_mean'] = [True, False]
param_grid['scaler__with_std'] = [True, False]
param_grid['knn__n_neighbors'] = [15, 20, 25, 30, 10, 50] 
param_grid['knn__weights'] = ['uniform', 'distance'] 
param_grid['knn__algorithm'] = ['auto', 'ball_tree', 'kd_tree', 'brute']
param_grid
# Out:
# {'imputer__strategy': ['mean', 'median'],
#  'scaler__with_mean': [True, False],
#  'scaler__with_std': [True, False],
#  'knn__n_neighbors': [15, 20, 25, 30, 10, 50],
#  'knn__weights': ['uniform', 'distance'],
#  'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']}

# %%
rand_knn = RandomizedSearchCV(pipe_knn, param_grid, cv=5, scoring='accuracy', n_iter=5, random_state=1)

# %%
# time the randomized search
# %time rand_knn.fit(X_train, y_train)
# Out:
# CPU times: user 3min 13s, sys: 1.99 s, total: 3min 15s
# Wall time: 3min 9s
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('knn', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))]),
#           fit_params=None, iid='warn', n_iter=5, n_jobs=None,
#           param_distributions={'imputer__strategy': ['mean', 'median'], 'scaler__with_mean': [True, False], 'scaler__with_std': [True, False], 'knn__n_neighbors': [15, 20, 25, 30, 10, 50], 'knn__weights': ['uniform', 'distance'], 'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']},
#           pre_dispatch='2*n_jobs', random_state=1, refit=True,
#           return_train_score='warn', scoring='accuracy', verbose=0)

# %%
print(rand_knn.best_score_) # hold-out set
print(rand_knn.best_params_)
# Out:
# 0.4379310344827586
# {'scaler__with_std': False, 'scaler__with_mean': True, 'knn__weights': 'uniform', 'knn__n_neighbors': 50, 'knn__algorithm': 'brute', 'imputer__strategy': 'mean'}

# %%
# print the best model found by RandomizedSearchCV
print(rand_knn.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=False)), ('knn', KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=50, p=2,
#            weights='uniform'))])

# %%
# predictions on train and test data with best estimator
y_trainpred_knn = rand_knn.predict(X_train)
y_pred_knn = rand_knn.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred_knn))
print(metrics.f1_score(y_test, y_pred_knn, average='macro'))
# Out:
# 0.45191313340227507
# 0.4493592262021139

# %%
# train set
print(metrics.accuracy_score(y_train, y_trainpred_knn))
print(metrics.f1_score(y_train, y_trainpred_knn, average='macro'))
# Out:
# 0.4748275862068966
# 0.4693067758301785

# %%
# pipe_knn.fit(X_train, y_train) # add randomized CV/grid search
# print("Train accuracy: ", pipe_knn.score(X_train, y_train))
# print("Test accuracy: ", pipe_knn.score(X_test, y_test))

# %% [markdown]
# ### Random Forest Classification

# %%
rf = RandomForestClassifier(random_state=0)
pipe_rf = Pipeline([('imputer', imputer),
                 ('scaler', scaler), 
                 ('rf', rf)])

# %%
param_grid = {}
param_grid['imputer__strategy'] = ["mean", "median"]
param_grid['scaler__with_mean'] = [True, False]
param_grid['scaler__with_std'] = [True, False]
param_grid['rf__n_estimators'] = [50, 100, 150, 200, 300, 500]  # how many trees to use in the forest
param_grid['rf__max_depth'] = [3, 5, 7, 9] # max depth
param_grid['rf__criterion'] = ['gini', 'entropy']
param_grid['rf__max_features'] = ['auto', 'log2'] # like mtry
param_grid
# Out:
# {'imputer__strategy': ['mean', 'median'],
#  'scaler__with_mean': [True, False],
#  'scaler__with_std': [True, False],
#  'rf__n_estimators': [50, 100, 150, 200, 300, 500],
#  'rf__max_depth': [3, 5, 7, 9],
#  'rf__criterion': ['gini', 'entropy'],
#  'rf__max_features': ['auto', 'log2']}

# %%
rand_rf = RandomizedSearchCV(pipe_rf, param_grid, cv=5, scoring='accuracy', n_iter=5, random_state=1)

# %%
# time the randomized search
# %time rand_rf.fit(X_train, y_train)
# Out:
# CPU times: user 25.1 s, sys: 930 ms, total: 26 s
# Wall time: 16.9 s
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('rf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, m...ors='warn', n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False))]),
#           fit_params=None, iid='warn', n_iter=5, n_jobs=None,
#           param_distributions={'imputer__strategy': ['mean', 'median'], 'scaler__with_mean': [True, False], 'scaler__with_std': [True, False], 'rf__n_estimators': [50, 100, 150, 200, 300, 500], 'rf__max_depth': [3, 5, 7, 9], 'rf__criterion': ['gini', 'entropy'], 'rf__max_features': ['auto', 'log2']},
#           pre_dispatch='2*n_jobs', random_state=1, refit=True,
#           return_train_score='warn', scoring='accuracy', verbose=0)

# %%
print(rand_rf.best_score_) # hold-out set
print(rand_rf.best_params_)
# Out:
# 0.4696551724137931
# {'scaler__with_std': False, 'scaler__with_mean': False, 'rf__n_estimators': 500, 'rf__max_features': 'log2', 'rf__max_depth': 9, 'rf__criterion': 'entropy', 'imputer__strategy': 'median'}

# %%
# print the best model found by RandomizedSearchCV
print(rand_rf.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan,
#        strategy='median', verbose=0)), ('scaler', StandardScaler(copy=True, with_mean=False, with_std=False)), ('rf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=...mators=500, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False))])

# %%
# predictions on train and test data with best estimator
y_trainpred_rf = rand_rf.predict(X_train)
y_pred_rf = rand_rf.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred_rf))
print(metrics.f1_score(y_test, y_pred_rf, average='macro'))
# Out:
# 0.49948293691830403
# 0.46833752264815975

# %%
# train set
print(metrics.accuracy_score(y_train, y_trainpred_rf))
print(metrics.f1_score(y_train, y_trainpred_rf, average='macro'))
# Out:
# 0.636551724137931
# 0.6191621151260325

# %%
# pipe_rf.fit(X_train, y_train) # add randomized CV/grid search
# print("Train accuracy: ", pipe_rf.score(X_train, y_train))
# print("Test accuracy: ", pipe_rf.score(X_test, y_test))
# Out:
# Train accuracy:  0.5420689655172414
# Test accuracy:  0.4984488107549121

# %%
# rf.feature_importances - cannot do this when using pipeline?

# %% [markdown]
# ### TODO modelling
# 0. Finalize evaluation metric - 1-away classification accuracy could be good - https://sud3010ganesh.github.io/2018-05-29-boxofficerevenueprediction/
# 1. Interpreting models - e.g., for RF, visualizing feature importance - https://towardsdatascience.com/how-to-visualize-a-decision-tree-from-a-random-forest-in-python-using-scikit-learn-38ad2d75f21c
# 2. Choose any other candidate models - neural networks, for example (like SNAP paper) or NB
# 3. Ensembling models/add to hyperparameter tuning above to improve performance
# 4. extension - setting y-variable (gross category) by K-means clustering gross revenue
